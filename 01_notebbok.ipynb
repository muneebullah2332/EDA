# %% [markdown]
# # 🍴✨ Unpacking the Annual School Meal Census 📚🔍 | A Full EDA Overview
#
# ![ChatGPT Image Apr 10, 2025, 11_55_28 PM.png](<attachment:ChatGPT Image Apr 10, 2025, 11_55_28 PM.png>)
#
# ## About Authur:
# - Name : Muhammad Muneebullah
# ### 🙋‍♂️ Let's Connect!
#
# Stay in touch for more awesome data stories and projects! 🚀
# You can find me on:
#
# ---
#
# | 🔗 Platform | 🌐 Link |
# |------------|---------|
# | 👔 **LinkedIn** | [Visit my profile](https://www.linkedin.com/in/muneebullah-muneeb-241393337/) |
# | 🧠 **Kaggle** | [Check out my notebooks](https://www.kaggle.com//muneebullahmuneeb) |
# | 📧 **Email** | [Contact me in Email](muneebullahmuneeb63@gmail.com) |
#
# ---
#
# ## About Dataset:(Meta Data)
#
# <table style="border-collapse: collapse; width: 100%; margin-top: 20px; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.1);">
#     <caption style="font-size: 1.5em; margin-bottom: 10px; color: red; font-weight: bold;">Annual School Meal Census Dataset</caption>
#     <thead>
#         <tr>
#             <th style="border: 1px solid #ddd; padding: 8px; background-color: #800080; color: white; font-weight: bold;">Column Name</th>
#             <th style="border: 1px solid #ddd; padding: 8px; background-color: #800080; color: white; font-weight: bold;">Description</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr style="background-color: #f9f9f9;">
#             <td style="border: 1px solid #ddd; padding: 8px; color: #800080;"><strong>Local Authority</strong></td>
#             <td style="border: 1px solid #ddd; padding: 8px; color: #1E90FF;">The local authority responsible for the school.</td>
#         </tr>
#         <tr>
#             <td style="border: 1px solid #ddd; padding: 8px; color: #800080;"><strong>School Name</strong></td>
#             <td style="border: 1px solid #ddd; padding: 8px; color: #1E90FF;">The name of the school.</td>
#         </tr>
#         <tr style="background-color: #f9f9f9;">
#             <td style="border: 1px solid #ddd; padding: 8px; color: #800080;"><strong>SeedCode</strong></td>
#             <td style="border: 1px solid #ddd; padding: 8px; color: #1E90FF;">A unique identifier for each school.</td>
#         </tr>
#         <tr>
#             <td style="border: 1px solid #ddd; padding: 8px; color: #800080;"><strong>School Type</strong></td>
#             <td style="border: 1px solid #ddd; padding: 8px; color: #1E90FF;">The type of school (e.g., primary, secondary).</td>
#         </tr>
#         <tr style="background-color: #f9f9f9;">
#             <td style="border: 1px solid #ddd; padding: 8px; color: #800080;"><strong>Roll</strong></td>
#             <td style="border: 1px solid #ddd; padding: 8px; color: #1E90FF;">Total number of students enrolled in the school.</td>
#         </tr>
#         <tr>
#             <td style="border: 1px solid #ddd; padding: 8px; color: #800080;"><strong>Number Registered for FSM</strong></td>
#             <td style="border: 1px solid #ddd; padding: 8px; color: #1E90FF;">The number of students registered for Free School Meals (FSM).</td>
#         </tr>
#         <tr style="background-color: #f9f9f9;">
#             <td style="border: 1px solid #ddd; padding: 8px; color: #800080;"><strong>Estimated Number Registered for FSM under National Eligibility only</strong></td>
#             <td style="border: 1px solid #ddd; padding: 8px; color: #1E90FF;">Estimated number of students eligible for FSM under national criteria.</td>
#         </tr>
#         <tr>
#             <td style="border: 1px solid #ddd; padding: 8px; color: #800080;"><strong>Pupils Present on Survey Day</strong></td>
#             <td style="border: 1px solid #ddd; padding: 8px; color: #1E90FF;">The total number of students present at school on the survey day.</td>
#         </tr>
#         <tr style="background-color: #f9f9f9;">
#             <td style="border: 1px solid #ddd; padding: 8px; color: #800080;"><strong>Pupils Present and Who Took a Meal (Free or Paid for)</strong></td>
#             <td style="border: 1px solid #ddd; padding: 8px; color: #1E90FF;">Number of students who were present and took a meal, either free or paid.</td>
#         </tr>
#         <tr>
#             <td style="border: 1px solid #ddd; padding: 8px; color: #800080;"><strong>Pupils Present and Registered for FSM</strong></td>
#             <td style="border: 1px solid #ddd; padding: 8px; color: #1E90FF;">Number of students who were present and are registered for FSM.</td>
#         </tr>
#         <tr style="background-color: #f9f9f9;">
#             <td style="border: 1px solid #ddd; padding: 8px; color: #800080;"><strong>Pupils Present and Who Took a FSM</strong></td>
#             <td style="border: 1px solid #ddd; padding: 8px; color: #1E90FF;">Number of students who were present and took a free school meal (FSM).</td>
#         </tr>
#         <tr>
#             <td style="border: 1px solid #ddd; padding: 8px; color: #800080;"><strong>Notes</strong></td>
#             <td style="border: 1px solid #ddd; padding: 8px; color: #1E90FF;">Any additional notes or comments related to the dataset or survey.</td>
#         </tr>
#     </tbody>
# </table>
#
# ## 📘 Table of Contents
#
#
# 1. [Step 1: Import Necessary Libraries](Step-1-Import-Necessary-Libraries)
# 2. [Step 2: Load the Dataset](Step-2-Load-the-dataset)
# 3. [Step 3: Understand The Data](step-3-understand-the-data)
# 4. [Step 4: Check Missing Values](step-4-check-missing-values)
# 5. [Step 5: Univariate Analysis](step-5-univariate-analysis)
# 6. [Step 6: Bivariate Analysis](step-6-bivariate-analysis)
# 7. [Step 7: Multivariate Analysis](step-7-multivariate-analysis)
# 8. [Step 8: Outlier Detection and Handle It](step-8-outlier-detection-and-handle-it)
# 9. [Step 9: Final View of Data](step-9-final-view-of-data)
#
#
# ## Aims:
# The aims of this project are to:
# - 🔍 Explore the data and understand the distribution of the variables.
# - 🛠️ Identify any missing values and if available, handle them.
# - 📊 Perform univariate, bivariate, and multivariate analysis to understand the relationship between the variables.
# - 🚨 Detect and handle outliers in the data.
# - 📏 Normalize the data if necessary.
#
# ## Using Libraries For this Project:
# - `pandas` for data manipulation and analysis.
# - `numpy` for numerical operations.
# - `matplotlib` and `seaborn` for data visualization.
# - `plotly`: for interactive plots.

# %% [markdown]
# <div style="font-family: 'Times New Roman', serif; background-color: #1E3A8A; color: #FF6347; padding: 15px 25px; font-size: 28px; font-weight: bold; border-radius: 15px; text-align: center;">
#     <span style="color: #87CEFA;">Step 1</span>: Import Necessary Libraries
# </div>

# %%
# import Libraries
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
pio.renderers.default = 'kaggle'
import warnings
warnings.filterwarnings('ignore')
# show maximum columns
pd.set_option('display.max_columns', None)
# show maximum rows
pd.set_option('display.max_rows', None)

# %% [markdown]
# <div style="font-family: 'Times New Roman', serif; background-color: #1E3A8A; color: #FF6347; padding: 15px 25px; font-size: 28px; font-weight: bold; border-radius: 15px; text-align: center;">
#     <span style="color: #87CEFA;">Step 2</span>: Load The Data
# </div>

# %% [markdown]
# - We Load the data from the CSV file into a pandas DataFrame.🌟

# %%
df = pd.read_csv('Annual School Meal Census_fsm2014.csv')

# %% [markdown]
# <div style="font-family: 'Times New Roman', serif; background-color: #1E3A8A; color: #FF6347; padding: 15px 25px; font-size: 28px; font-weight: bold; border-radius: 15px; text-align: center;">
#     <span style="color: #87CEFA;">Step 3</span>: Understand The Data
# </div>

# %% [markdown]
# Let's see the shape of the dataset. 🧐

# %%
print('The Number Of Rows in this DataSet is', df.shape[0], 'And Number of Columns In This Dataset is', df.shape[1])
# Out:
# The Number Of Rows in this DataSet is 194 And Number of Columns In This Dataset is 12

# %% [markdown]
# Let's see all the information about the dataset. 📋

# %%
df.info() # the info() command is used to get information about the data.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 12 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Local Authority                                                      194 non-null    object
#  1   School Name                                                          194 non-null    object
#  2   SeedCode                                                             194 non-null    int64
#  3   School Type                                                          194 non-null    object
#  4   Roll                                                                 194 non-null    int64
#  5   Number registered for FSM                                            194 non-null    int64
#  6   Estimated Number registered for FSM under National eligibility only  194 non-null    int64
# ...

# %% [markdown]
# - Here we see there are only three object columns and all other numerical columns. 🔢

# %% [markdown]
# - Let's Wee see the Statistical Summary In the dataset 📊

# %%
df.describe().T # T is used to transpose the dataframe
# Out:
#                                                     count          mean  \
# SeedCode                                            194.0  8.351269e+06
# Roll                                                194.0  3.345515e+02
# Number registered for FSM                           194.0  1.094227e+02
# Estimated Number registered for FSM under Natio...  194.0  1.094227e+02
# Pupils Present on survey day                        194.0  3.058144e+02
# Pupils Present and who took a meal (free or pai...  194.0  1.557320e+02
# Pupils Present and Registered for FSM               194.0  9.719072e+01
# Pupils Present and who took a FSM                   194.0  8.120619e+01
# Notes                                               194.0  0.000000e+00
#
#                                                               std        min  \
# SeedCode                                            752278.731625  1000241.0
# Roll                                                   292.709621       24.0
# ...

# %% [markdown]
# - Here we see only the Columns in the data. 📋

# %%
df.columns
# Out:
# Index(['Local Authority', 'School Name', 'SeedCode', 'School Type', 'Roll',
#        'Number registered for FSM',
#        'Estimated Number registered for FSM under National eligibility only',
#        'Pupils Present on survey day',
#        'Pupils Present and who took a meal (free or paid for)',
#        'Pupils Present and Registered for FSM',
#        'Pupils Present and who took a FSM', 'Notes'],
#       dtype='object')

# %% [markdown]
# <div style="font-family: 'Times New Roman', serif; background-color: #1E3A8A; color: #FF6347; padding: 15px 25px; font-size: 28px; font-weight: bold; border-radius: 15px; text-align: center;">
#     <span style="color: #87CEFA;">Step 4</span>: Check Missing Values
# </div>

# %% [markdown]
# - 🔍 Let's Check the Missing Values In the Dataset

# %%
df.isnull().sum()
# Out:
# Local Authority                                                        0
# School Name                                                            0
# SeedCode                                                               0
# School Type                                                            0
# Roll                                                                   0
# Number registered for FSM                                              0
# Estimated Number registered for FSM under National eligibility only    0
# Pupils Present on survey day                                           0
# Pupils Present and who took a meal (free or paid for)                  0
# Pupils Present and Registered for FSM                                  0
# Pupils Present and who took a FSM                                      0
# Notes                                                                  0
# dtype: int64

# %% [markdown]
# - Here we See there is no missing value in this dataset. 🎉✨ It is Good For us! 👍

# %% [markdown]
# - 🔍✨ Let's again check the missing values using the `round` function and see the percentage in descending order. 📊📉

# %%
round((df.isnull().sum() / len(df)) * 100, 2).sort_index(ascending=False)
# Out:
# SeedCode                                                               0.0
# School Type                                                            0.0
# School Name                                                            0.0
# Roll                                                                   0.0
# Pupils Present on survey day                                           0.0
# Pupils Present and who took a meal (free or paid for)                  0.0
# Pupils Present and who took a FSM                                      0.0
# Pupils Present and Registered for FSM                                  0.0
# Number registered for FSM                                              0.0
# Notes                                                                  0.0
# Local Authority                                                        0.0
# Estimated Number registered for FSM under National eligibility only    0.0
# dtype: float64

# %% [markdown]
# - 🔍✨ Let's see the missing values through visualization using the seaborn library 📊🎨

# %%
sns.heatmap(df.isnull(), annot=True, cmap='coolwarm', cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# <div style="font-family: 'Times New Roman', serif; background-color: #1E3A8A; color: #FF6347; padding: 15px 25px; font-size: 28px; font-weight: bold; border-radius: 15px; text-align: center;">
#     <span style="color: #87CEFA;">Step 5</span>: Univariate Analysis
# </div>

# %% [markdown]
# #### ✨📊 Let's Jump into the Univariate Analysis 🎯📈

# %% [markdown]
# - ✨📋 Let's check the Specific Columns One By One 🎯🔍

# %%
# lets check thr Local Authority columns
df['Local Authority'].unique()
# Out:
# array(['Glasgow City'], dtype=object)

# %% [markdown]
# - Here we see the unique value in this column is Glasgow City 🌆✨

# %%
# lets check the number of unique value in the column
df['Local Authority'].nunique()
# Out:
# 1

# %% [markdown]
# - Obviously the Unique Value is one and the Number of unique Value is also one 😳

# %%
# lets we see the number of unique values 
df['School Name'].nunique()
# Out:
# 193

# %% [markdown]
# - 🌟 Here we see the Number of Unique Values in School name is 193. 🎓✨

# %%
df['School Name'].value_counts().head(10)
# Out:
# School Name
# Glasgow Gaelic School              2
# Highpark Primary School            1
# Camstradden Primary School         1
# Oakwood Primary School             1
# Riverside Primary School           1
# Alexandra Parade Primary School    1
# Anderston Primary School           1
# Annette Street Primary School      1
# Balornock Primary School           1
# Bankhead Primary School            1
# Name: count, dtype: int64

# %% [markdown]
# - 🌟 Here we check the first 10 rows of the value counts of the School name column 📋✨

# %%
# lets check the schhol type columns
df['School Type'].unique()
# Out:
# array(['Special', 'Primary', 'Secondary'], dtype=object)

# %% [markdown]
# - 🌟 Here we See the unique values and Obviously the number of unique value of this column is 3. 🎯✨

# %%
# here we check the value counts of the Pupils Present on survey day columns
df['Pupils Present on survey day'].value_counts().head(15)
# Out:
# Pupils Present on survey day
# 165    3
# 378    3
# 192    3
# 240    2
# 319    2
# 135    2
# 287    2
# 245    2
# 119    2
# 108    2
# 211    2
# 197    2
# 273    2
# 250    2
# 302    2
# Name: count, dtype: int64

# %% [markdown]
# - 🌟 Here we see the value counts of the Pupils Present on survey day columns. 📋✨

# %% [markdown]
# - Lets make the histgram plot of the Pupils Present on survey day column for see the distribution of the data

# %%
sns.histplot(df, x = 'Pupils Present on survey day', kde=True)
# Out:
# <Axes: xlabel='Pupils Present on survey day', ylabel='Count'>

# %% [markdown]
# - 🌟 Here we see the data is very skewed. We will handle this using the logarithmic transformation. 📉✨

# %%
# lets handle the skewness in the Pupils Present on survey day columns
df['Pupils Present on survey day'] = np.log(df['Pupils Present on survey day']+ 1)

# %% [markdown]
# - 🌟 Here we handle the skewness of the data. 📉✨

# %%
# lets again plot the column
sns.histplot(df, x = 'Pupils Present on survey day', kde=True)
# Out:
# <Axes: xlabel='Pupils Present on survey day', ylabel='Count'>

# %% [markdown]
# - 🌟 Here we see with proof the data is normalized. 📊✨

# %%
# lets check the normalization of the Number registered for FSM column
sns.histplot(df, x= 'Number registered for FSM', kde=True)
# Out:
# <Axes: xlabel='Number registered for FSM', ylabel='Count'>

# %% [markdown]
# - 🌟 Here we see this column is skewed. Let's handle this by using log transformation. 📉✨

# %%
df['Number registered for FSM'] = np.log(df['Number registered for FSM']+ 1)

# %% [markdown]
# - 🌟 Here we normalize the column. 📉✨

# %%
sns.histplot(df, x= 'Number registered for FSM', kde=True)
# Out:
# <Axes: xlabel='Number registered for FSM', ylabel='Count'>

# %% [markdown]
# - 🌟 Here we see with proof the data is normalized. 📊✨

# %% [markdown]
# - 📊✨ Let's see the bar plot of the school type based on the seedcode with interactive Plotly library. 🚀📈

# %%
fig = px.bar(data_frame=df, x = 'School Type', y = 'SeedCode', title = 'School Type Based on the SeedCode')
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %% [markdown]
# - 📊✨ This is a Bar plot. You can check it; this is very interactive! 🚀🎉

# %% [markdown]
# <div style="font-family: 'Times New Roman', serif; background-color: #1E3A8A; color: #FF6347; padding: 15px 25px; font-size: 28px; font-weight: bold; border-radius: 15px; text-align: center;">
#     <span style="color: #87CEFA;">Step 6</span>: Bivariate Analysis
# </div>

# %% [markdown]
# #### ✨📊 Let's We Perform the Bivariate Analysis 🎯📈

# %% [markdown]
# - ✨📊 First, we make the Correlation plot to see the correlation between the numeric variables 🔍📈

# %%
corr_matrix = df.select_dtypes(include=['int', 'float']).corr()
# Plot the corr_matrix using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', square=True)
# Out:
# <Axes: >

# %% [markdown]
# - 🌟 Here we see the correlation plot. You can see the correlation between the columns. 📊✨

# %% [markdown]
# - ✨📊 Let's we make the scatter plot between the two columns. 🎯📈

# %%
fig = px.scatter(data_frame=df, x='Number registered for FSM', y='Pupils Present on survey day', title='Number Registered for FSM vs Pupils present on survey day')
fig.update_traces(marker=dict(color='red'))
fig.show()
# Out:
# <div>                            <div id="48771171-3eb7-4527-ad2b-415224c8b624" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("48771171-3eb7-4527-ad2b-415224c8b624")) {                    Plotly.newPlot(                        "48771171-3eb7-4527-ad2b-415224c8b624",                        [{"hovertemplate":"Number registered for FSM=%{x}\u003cbr\u003ePupils Present on survey day=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"red","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[3.295836866004329,4.663439094112067,4.709530201312334,4.897839799950911,4.634728988229636,4.77912349311153,3.6109179126442243,4.543294782270004,5.099866427824199,4.859812404361672,3.970291913552122,4.3
# ...

# %% [markdown]
# - Here we see the Scatter Plot between the tow columns .This Interactive plot🌟✨

# %% [markdown]
# - ✨📊 Let's see the pairplot of the data 🔍📈

# %%
sns.pairplot(df)

# %% [markdown]
# - 🌟 Here We see the pairplot of the data 📊✨

# %% [markdown]
# <div style="font-family: 'Times New Roman', serif; background-color: #1E3A8A; color: #FF6347; padding: 15px 25px; font-size: 28px; font-weight: bold; border-radius: 15px; text-align: center;">
#     <span style="color: #87CEFA;">Step 7</span>: MultiVariate Analysis
# </div>

# %% [markdown]
# #### ✨📊 Let's We Perform the Multivariate Analysis 🎯📈

# %% [markdown]
# - ✨📊 First, we use the `groupby` function to see the grouping of the columns. 🎯🔍

# %%
df.groupby('Pupils Present on survey day')['School Type'].value_counts().head(15)
# Out:
# Pupils Present on survey day  School Type
# 3.178054                      Special        1
# 3.218876                      Special        1
# 3.433987                      Special        1
# 3.555348                      Special        1
# 3.610918                      Special        2
# 3.663562                      Special        1
# 3.688879                      Special        1
# 3.737670                      Special        1
# 3.784190                      Special        1
# 3.806662                      Special        1
# 3.828641                      Special        1
# 3.951244                      Special        2
# 3.988984                      Special        1
# 4.025352                      Special        1
# 4.094345                      Special        1
# Name: count, dtype: int64

# %%
df.groupby('Roll')['Pupils Present and who took a meal (free or paid for)'].value_counts().head(15)
# Out:
# Roll  Pupils Present and who took a meal (free or paid for)
# 24    10                                                       1
# 34    34                                                       1
# 36    36                                                       1
# 40    39                                                       1
# 41    41                                                       1
# 43    37                                                       1
# 44    10                                                       1
# 45    32                                                       1
# 52    37                                                       1
#       44                                                       1
# 53    40                                                       1
# 54    43                                                       1
# 55    40                                                       1
# 58    55                                                       1
# ...

# %% [markdown]
# - 🌟✨ Let's we Make the 3D Scatter Interactive Plot for gaining more information 📊🎯

# %%
fig = px.scatter_3d(
    data_frame=df,
    x='Number registered for FSM',
    y='Pupils Present and Registered for FSM',
    z='Pupils Present and who took a meal (free or paid for)',
    color='School Type',  # Separate colors based on the 'School Type' column
    title='3D Scatter Plot with Color Separation by School Type'
)
fig.show()
# Out:
# <div>                            <div id="05ae61ef-4f8f-499f-a739-6d60e47f0eb4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("05ae61ef-4f8f-499f-a739-6d60e47f0eb4")) {                    Plotly.newPlot(                        "05ae61ef-4f8f-499f-a739-6d60e47f0eb4",                        [{"hovertemplate":"School Type=Special\u003cbr\u003eNumber registered for FSM=%{x}\u003cbr\u003ePupils Present and Registered for FSM=%{y}\u003cbr\u003ePupils Present and who took a meal (free or paid for)=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Special","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Special","scene":"scene","showlegend":true,"x":[3.295836866004329,4.406719247264253,1.9459101490553132,2.833213344056216
# ...

# %% [markdown]
# - 🌟 Such a beautiful plot! 🎨✨

# %% [markdown]
# - 🌟✨ Let's make the more Interactive and stylish sunburst plot 🌞🎨

# %%
fig = px.sunburst(
    df,
    path=['Local Authority', 'School Type', 'School Name'],  # Hierarchical levels
    values='Roll',  # Size of the segments
    title='Sunburst Plot of School Data',
    color='School Type',  # Color segments by School Type
    color_discrete_sequence=px.colors.qualitative.Set3  # Set color palette
)
fig.show()
# Out:
# <div>                            <div id="ab8ab306-4d0a-4d1a-8dde-1b3208649881" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ab8ab306-4d0a-4d1a-8dde-1b3208649881")) {                    Plotly.newPlot(                        "ab8ab306-4d0a-4d1a-8dde-1b3208649881",                        [{"branchvalues":"total","customdata":[["Primary"],["Secondary"],["Special"],["Primary"],["Primary"],["Primary"],["Primary"],["Special"],["Primary"],["Special"],["Primary"],["Secondary"],["Primary"],["Primary"],["Secondary"],["Special"],["Primary"],["Special"],["Special"],["Primary"],["Secondary"],["Primary"],["Secondary"],["Primary"],["Primary"],["Special"],["Primary"],["Secondary"],["Special"],["Primary"],["Secondary"],["Primary"],["Primary"],["Primary"],["Prima
# ...

# %% [markdown]
# - 🌟✨ Level Plot for Multivariate Analysis 🎨📊

# %% [markdown]
# - 🌟 Guize, Let's make the parallel coordinate plot for gaining more info 📊✨

# %%
fig = px.parallel_coordinates(
    df,
    dimensions=[
        'Roll',
        'Number registered for FSM',
        'Estimated Number registered for FSM under National eligibility only',
        'Pupils Present on survey day',
        'Pupils Present and who took a meal (free or paid for)',
        'Pupils Present and Registered for FSM',
        'Pupils Present and who took a FSM'
    ],
    color='Roll',  # Color the lines based on the 'Roll' column
    title='Parallel Coordinates Plot of School Data'
)
fig.show()
# Out:
# <div>                            <div id="80d7af3a-7848-4847-a82e-c582caeb9143" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("80d7af3a-7848-4847-a82e-c582caeb9143")) {                    Plotly.newPlot(                        "80d7af3a-7848-4847-a82e-c582caeb9143",                        [{"dimensions":[{"label":"Roll","values":[61,190,198,242,203,376,111,179,311,333,97,338,210,419,423,164,354,423,172,268,367,219,359,264,272,302,334,281,260,260,216,322,253,220,141,127,143,651,341,171,480,276,407,183,443,320,491,385,381,208,403,489,424,125,147,236,213,407,210,201,391,242,259,130,258,260,307,346,259,294,279,324,350,173,319,216,339,208,229,88,243,236,481,312,204,194,227,250,218,160,202,280,233,328,210,231,173,349,287,174,301,386,192,290,129,185,326,4
# ...

# %% [markdown]
# - Awesome plot📊✨

# %% [markdown]
# <div style="font-family: 'Times New Roman', serif; background-color: #1E3A8A; color: #FF6347; padding: 15px 25px; font-size: 28px; font-weight: bold; border-radius: 15px; text-align: center;">
#     <span style="color: #87CEFA;">Step 8</span>: Outlier Detection And Handle it.
# </div>

# %% [markdown]
# #### 🌟✨ Let's Detect the Outlier and Handle It! 🚀📊

# %% [markdown]
# - 🌟✨ First, we see the boxplot of all numeric variables in the dataset for detection. 📊🔍

# %%
# Plot all numeric columns in one big square plot with different colors for each box plot
numeric_columns = df.select_dtypes(include=['int64', 'float64']).columns
colors = sns.color_palette("husl", len(numeric_columns))  # Generate a color palette

plt.figure(figsize=(12, 12))  # Set the figure size
for i, col in enumerate(numeric_columns, 1):
    plt.subplot(int(len(numeric_columns)**0.5) + 1, int(len(numeric_columns)**0.5) + 1, i)
    sns.boxplot(y=df[col], color=colors[i - 1])
    plt.title(col, fontsize=10)
    plt.tight_layout()
plt.show()

# %% [markdown]
# 🌟✨ Here we see the outlier in the Roll column and Pupils Present and who took a FSM column. Let's handle it! 🚀📊

# %%
df = df[df['Roll'] < 2000]

# %%
sns.boxplot(df['Roll'])
# Out:
# <Axes: ylabel='Roll'>

# %%
df = df[df['Pupils Present and who took a FSM'] < 350]
sns.boxplot(df['Pupils Present and who took a FSM'])
# Out:
# <Axes: ylabel='Pupils Present and who took a FSM'>

# %% [markdown]
# <div style="font-family: 'Times New Roman', serif; background-color: #1E3A8A; color: #FF6347; padding: 15px 25px; font-size: 28px; font-weight: bold; border-radius: 15px; text-align: center;">
#     <span style="color: #87CEFA;">Step 9</span>: Final View On the data
# </div>

# %%
# lets final view on the data
df.head(10)
# Out:
#   Local Authority                      School Name  SeedCode School Type  \
# 0    Glasgow City             Westmuir High School   1000241     Special
# 1    Glasgow City          Highpark Primary School   1001507     Primary
# 2    Glasgow City       Camstradden Primary School   8400024     Primary
# 3    Glasgow City           Oakwood Primary School   8400121     Primary
# 4    Glasgow City         Riverside Primary School   8400229     Primary
# 5    Glasgow City  Alexandra Parade Primary School   8405328     Primary
# 6    Glasgow City         Anderston Primary School   8405425     Primary
# 7    Glasgow City    Annette Street Primary School   8405522     Primary
# 8    Glasgow City         Balornock Primary School   8405921     Primary
# 9    Glasgow City          Bankhead Primary School   8406022     Primary
#
#    Roll  Number registered for FSM  \
# 0    61                   3.295837
# 1   190                   4.663439
# 2   198                   4.709530
# ...

# %% [markdown]
# - 🌟✨ **Plz Give Me the Supports 🙏. I Need your supports for growing in the kaggle 🚀📊**

# %% [markdown]
# Note: Some parts of this notebook were developed with the assistance of AI tools, with only minor code elements used. The content has been reviewed, customized, and verified to ensure accuracy and originality.
